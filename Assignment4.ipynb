# %% [markdown]
# <a href="https://colab.research.google.com/github/Archangelphrank/BNF-5507-Materials/blob/main/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# General
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Survival Models
from lifelines import KaplanMeierFitter, CoxPHFitter
from lifelines.statistics import logrank_test
from sksurv.ensemble import RandomSurvivalForest
from sksurv.util import Surv
from sksurv.metrics import concordance_index_censored

# Modeling
from sklearn.model_selection import train_test_split

# %%
# %pip install lifelines scikit-survival
# Out:
# Collecting lifelines
#   Downloading lifelines-0.30.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting scikit-survival
#   Downloading scikit_survival-0.24.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from lifelines) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from lifelines) (1.15.3)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.11/dist-packages (from lifelines) (2.2.2)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.11/dist-packages (from lifelines) (3.10.0)
# Requirement already satisfied: autograd>=1.5 in /usr/local/lib/python3.11/dist-packages (from lifelines) (1.8.0)
# Collecting autograd-gamma>=0.3 (from lifelines)
#   Downloading autograd-gamma-0.5.0.tar.gz (4.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting formulaic>=0.2.2 (from lifelines)
#   Downloading formulaic-1.1.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting ecos (from scikit-survival)
#   Downloading ecos-2.0.14-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.0 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from scikit-survival) (1.5.1)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.11/dist-packages (from scikit-survival) (2.11.0)
# Collecting osqp<1.0.0,>=0.6.3 (from scikit-survival)
#   Downloading osqp-0.6.7.post3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Requirement already satisfied: scikit-learn<1.7,>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from scikit-survival) (1.6.1)
# Collecting interface-meta>=1.2.0 (from formulaic>=0.2.2->lifelines)
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=0.2.2->lifelines) (4.14.0)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=0.2.2->lifelines) (1.17.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines) (2.9.0.post0)
# Collecting qdldl (from osqp<1.0.0,>=0.6.3->scikit-survival)
#   Downloading qdldl-0.1.7.post5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->lifelines) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->lifelines) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<1.7,>=1.6.1->scikit-survival) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0->lifelines) (1.17.0)
# Downloading lifelines-0.30.0-py3-none-any.whl (349 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.3/349.3 kB 14.7 MB/s eta 0:00:00
# Downloading scikit_survival-0.24.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 90.4 MB/s eta 0:00:00
# Downloading formulaic-1.1.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.7/115.7 kB 9.5 MB/s eta 0:00:00
# Downloading osqp-0.6.7.post3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (298 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.3/298.3 kB 27.8 MB/s eta 0:00:00
# Downloading ecos-2.0.14-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (220 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.1/220.1 kB 21.5 MB/s eta 0:00:00
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Downloading qdldl-0.1.7.post5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 65.0 MB/s eta 0:00:00
# Building wheels for collected packages: autograd-gamma
#   Building wheel for autograd-gamma (setup.py) ... done
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4030 sha256=06acaf044e78753bd1266d853599a0eb1875447d3e2e74a182228dd1041c62ef
#   Stored in directory: /root/.cache/pip/wheels/8b/67/f4/2caaae2146198dcb824f31a303833b07b14a5ec863fb3acd7b
# Successfully built autograd-gamma
# Installing collected packages: interface-meta, qdldl, ecos, autograd-gamma, osqp, formulaic, scikit-survival, lifelines
#   Attempting uninstall: osqp
#     Found existing installation: osqp 1.0.4
#     Uninstalling osqp-1.0.4:
#       Successfully uninstalled osqp-1.0.4
# Successfully installed autograd-gamma-0.5.0 ecos-2.0.14 formulaic-1.1.1 interface-meta-1.3.0 lifelines-0.30.0 osqp-0.6.7.post3 qdldl-0.1.7.post5 scikit-survival-0.24.1

# %%
df = pd.read_excel("Data/RADCURE_Clinical_v04_20241219.xlsx")
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3346 entries, 0 to 3345
# Data columns (total 34 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   patient_id         3346 non-null   object
#  1   Age                3346 non-null   float64
#  2   Sex                3346 non-null   object
#  3   ECOG PS            3345 non-null   object
#  4   Smoking PY         3341 non-null   object
#  5   Smoking Status     3346 non-null   object
#  6   Ds Site            3346 non-null   object
#  7   Subsite            2972 non-null   object
#  8   T                  3334 non-null   object
#  9   N                  3333 non-null   object
#  10  M                  3332 non-null   object
#  11  Stage              3319 non-null   object
#  12  Path               3346 non-null   object
#  13  HPV                1717 non-null   object
#  14  Tx Modality        3346 non-null   object
#  15  Chemo              3346 non-null   object
#  16  RT Start           3346 non-null   datetime64[ns]
#  17  Dose               3346 non-null   float64
#  18  Fx                 3346 non-null   int64
#  19  Last FU            3346 non-null   datetime64[ns]
#  20  Status             3346 non-null   object
#  21  Length FU          3346 non-null   float64
#  22  Date of Death      1058 non-null   datetime64[ns]
#  23  Cause of Death     1052 non-null   object
#  24  Local              380 non-null    object
#  25  Date Local         380 non-null    datetime64[ns]
#  26  Regional           189 non-null    object
#  27  Date Regional      189 non-null    datetime64[ns]
#  28  Distant            413 non-null    object
#  29  Date Distant       413 non-null    datetime64[ns]
#  30  2nd Ca             441 non-null    object
#  31  Date 2nd Ca        439 non-null    datetime64[ns]
#  32  RADCURE-challenge  3346 non-null   object
#  33  ContrastEnhanced   3346 non-null   int64
# dtypes: datetime64[ns](7), float64(3), int64(2), object(22)
# memory usage: 888.9+ KB

# %%
# Copy for processing

df_clean =df.copy()
df_clean.columns = df_clean.columns.str.strip()
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3346 entries, 0 to 3345
# Data columns (total 34 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   patient_id         3346 non-null   object
#  1   Age                3346 non-null   float64
#  2   Sex                3346 non-null   object
#  3   ECOG PS            3345 non-null   object
#  4   Smoking PY         3341 non-null   object
#  5   Smoking Status     3346 non-null   object
#  6   Ds Site            3346 non-null   object
#  7   Subsite            2972 non-null   object
#  8   T                  3334 non-null   object
#  9   N                  3333 non-null   object
#  10  M                  3332 non-null   object
#  11  Stage              3319 non-null   object
#  12  Path               3346 non-null   object
#  13  HPV                1717 non-null   object
#  14  Tx Modality        3346 non-null   object
#  15  Chemo              3346 non-null   object
#  16  RT Start           3346 non-null   datetime64[ns]
#  17  Dose               3346 non-null   float64
#  18  Fx                 3346 non-null   int64
#  19  Last FU            3346 non-null   datetime64[ns]
#  20  Status             3346 non-null   object
#  21  Length FU          3346 non-null   float64
#  22  Date of Death      1058 non-null   datetime64[ns]
#  23  Cause of Death     1052 non-null   object
#  24  Local              380 non-null    object
#  25  Date Local         380 non-null    datetime64[ns]
#  26  Regional           189 non-null    object
#  27  Date Regional      189 non-null    datetime64[ns]
#  28  Distant            413 non-null    object
#  29  Date Distant       413 non-null    datetime64[ns]
#  30  2nd Ca             441 non-null    object
#  31  Date 2nd Ca        439 non-null    datetime64[ns]
#  32  RADCURE-challenge  3346 non-null   object
#  33  ContrastEnhanced   3346 non-null   int64
# dtypes: datetime64[ns](7), float64(3), int64(2), object(22)
# memory usage: 888.9+ KB

# %%
print(df_clean.columns.tolist())
# Out:
# ['patient_id', 'Age', 'Sex', 'ECOG PS', 'Smoking PY', 'Smoking Status', 'Ds Site', 'Subsite', 'T', 'N', 'M', 'Stage', 'Path', 'HPV', 'Tx Modality', 'Chemo', 'RT Start', 'Dose', 'Fx', 'Last FU', 'Status', 'Length FU', 'Date of Death', 'Cause of Death', 'Local', 'Date Local', 'Regional', 'Date Regional', 'Distant', 'Date Distant', '2nd Ca', 'Date 2nd Ca', 'RADCURE-challenge', 'ContrastEnhanced']

# %%
# Define event column from Status
df_clean["event"] = df_clean["Status"].str.lower().eq("dead").astype(int)
# Check event distribution
df_clean["event"].value_counts()
# Out:
# event
# 0    2288
# 1    1058
# Name: count, dtype: int64

# %%
df_clean["time"] = np.where(
    df_clean["event"] == 1,
    (df_clean["Date of Death"] - df_clean["RT Start"]).dt.days,
    (df_clean["Last FU"] - df_clean["RT Start"]).dt.days
)

# Confirm it's there
df_clean[["time", "event", "Age", "Sex", "ECOG PS", "Smoking PY"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3346 entries, 0 to 3345
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   time        3346 non-null   float64
#  1   event       3346 non-null   int64
#  2   Age         3346 non-null   float64
#  3   Sex         3346 non-null   object
#  4   ECOG PS     3345 non-null   object
#  5   Smoking PY  3341 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 157.0+ KB

# %%
df_clean.describe(include="all").T
# Out:
#                     count unique                      top   freq  \
# patient_id           3346   3346             RADCURE-4130      1
# Age                3346.0    NaN                      NaN    NaN
# Sex                  3346      2                     Male   2660
# ECOG PS              3345     10                   ECOG 0   2025
# Smoking PY         3341.0  100.0                      0.0  871.0
# Smoking Status       3346      4                Ex-smoker   1290
# Ds Site              3346     19               Oropharynx   1501
# Subsite              2972     63                  Glottis    630
# T                    3334     17                       T2    927
# N                    3333     10                       N0   1147
# M                    3332      3                       M0   3328
# Stage                3319     14                      IVA   1581
# Path                 3346     41  Squamous Cell Carcinoma   2847
# HPV                  1717      2            Yes, positive   1139
# Tx Modality          3346      5                 RT alone   1858
# Chemo                3346      2                     none   1923
# RT Start             3346    NaN                      NaN    NaN
# Dose               3346.0    NaN                      NaN    NaN
# Fx                 3346.0    NaN                      NaN    NaN
# Last FU              3346    NaN                      NaN    NaN
# Status               3346      2                    Alive   2288
# Length FU          3346.0    NaN                      NaN    NaN
# Date of Death        1058    NaN                      NaN    NaN
# Cause of Death       1052     24             Index Cancer    505
# Local                 380      3                      Yes    306
# Date Local            380    NaN                      NaN    NaN
# Regional              189      3                      Yes    146
# Date Regional         189    NaN                      NaN    NaN
# Distant               413      3                      Yes    407
# Date Distant          413    NaN                      NaN    NaN
# 2nd Ca                441      2                        Y    430
# Date 2nd Ca           439    NaN                      NaN    NaN
# RADCURE-challenge    3346      3                 training   1800
# ContrastEnhanced   3346.0    NaN                      NaN    NaN
# event              3346.0    NaN                      NaN    NaN
# time               3346.0    NaN                      NaN    NaN
#
#                                             mean                  min  \
# patient_id                                   NaN                  NaN
# Age                                    62.300418                 15.6
# Sex                                          NaN                  NaN
# ECOG PS                                      NaN                  NaN
# Smoking PY                                   NaN                  NaN
# Smoking Status                               NaN                  NaN
# Ds Site                                      NaN                  NaN
# Subsite                                      NaN                  NaN
# T                                            NaN                  NaN
# N                                            NaN                  NaN
# M                                            NaN                  NaN
# Stage                                        NaN                  NaN
# Path                                         NaN                  NaN
# HPV                                          NaN                  NaN
# Tx Modality                                  NaN                  NaN
# Chemo                                        NaN                  NaN
# RT Start           2005-05-11 00:38:43.968918016  1999-02-07 00:00:00
# Dose                                    66.65824                 50.0
# Fx                                     33.024806                 20.0
# Last FU            2009-05-09 01:23:03.622235648  1999-06-22 00:00:00
# Status                                       NaN                  NaN
# Length FU                               4.136047             0.156164
# Date of Death      2006-06-11 08:31:45.482041600  1999-06-22 00:00:00
# Cause of Death                               NaN                  NaN
# Local                                        NaN                  NaN
# Date Local         2006-01-25 13:34:44.210526336  1999-05-18 00:00:00
# Regional                                     NaN                  NaN
# Date Regional      2006-01-08 02:55:14.285714304  1999-05-18 00:00:00
# Distant                                      NaN                  NaN
# Date Distant       2006-08-04 02:05:31.234866944  1999-08-30 00:00:00
# 2nd Ca                                       NaN                  NaN
# Date 2nd Ca        2006-06-29 06:27:03.690205056  1999-05-26 00:00:00
# RADCURE-challenge                            NaN                  NaN
# ContrastEnhanced                        0.601614                  0.0
# event                                   0.316198                  0.0
# time                                 1459.006874                 21.0
#
#                                    25%                  50%  \
# patient_id                         NaN                  NaN
# Age                               54.5                 62.1
# Sex                                NaN                  NaN
# ECOG PS                            NaN                  NaN
# Smoking PY                         NaN                  NaN
# Smoking Status                     NaN                  NaN
# Ds Site                            NaN                  NaN
# Subsite                            NaN                  NaN
# T                                  NaN                  NaN
# N                                  NaN                  NaN
# M                                  NaN                  NaN
# Stage                              NaN                  NaN
# Path                               NaN                  NaN
# HPV                                NaN                  NaN
# Tx Modality                        NaN                  NaN
# Chemo                              NaN                  NaN
# RT Start           2002-07-23 06:00:00  2005-06-18 00:00:00
# Dose                              64.0                 70.0
# Fx                                35.0                 35.0
# Last FU            2007-06-25 00:00:00  2010-06-22 00:00:00
# Status                             NaN                  NaN
# Length FU                     1.879452             3.663014
# Date of Death      2004-02-14 12:00:00  2006-09-14 12:00:00
# Cause of Death                     NaN                  NaN
# Local                              NaN                  NaN
# Date Local         2003-01-28 06:00:00  2006-01-05 12:00:00
# Regional                           NaN                  NaN
# Date Regional      2003-01-21 00:00:00  2006-05-10 00:00:00
# Distant                            NaN                  NaN
# Date Distant       2004-01-12 00:00:00  2006-07-02 00:00:00
# 2nd Ca                             NaN                  NaN
# Date 2nd Ca        2003-12-07 00:00:00  2006-09-11 00:00:00
# RADCURE-challenge                  NaN                  NaN
# ContrastEnhanced                   0.0                  1.0
# event                              0.0                  0.0
# time                             640.0               1288.0
#
#                                    75%                  max         std
# patient_id                         NaN                  NaN         NaN
# Age                               70.3                 90.0   11.645892
# Sex                                NaN                  NaN         NaN
# ECOG PS                            NaN                  NaN         NaN
# Smoking PY                         NaN                  NaN         NaN
# Smoking Status                     NaN                  NaN         NaN
# Ds Site                            NaN                  NaN         NaN
# Subsite                            NaN                  NaN         NaN
# T                                  NaN                  NaN         NaN
# N                                  NaN                  NaN         NaN
# M                                  NaN                  NaN         NaN
# Stage                              NaN                  NaN         NaN
# Path                               NaN                  NaN         NaN
# HPV                                NaN                  NaN         NaN
# Tx Modality                        NaN                  NaN         NaN
# Chemo                              NaN                  NaN         NaN
# RT Start           2008-04-19 18:00:00  2011-03-21 00:00:00         NaN
# Dose                              70.0                 74.0    5.754948
# Fx                                35.0                 60.0    5.206841
# Last FU            2011-12-04 18:00:00  2012-06-30 00:00:00         NaN
# Status                             NaN                  NaN         NaN
# Length FU                     5.791781            12.909589    2.734757
# Date of Death      2008-10-28 00:00:00  2012-04-07 00:00:00         NaN
# Cause of Death                     NaN                  NaN         NaN
# Local                              NaN                  NaN         NaN
# Date Local         2009-01-02 12:00:00  2012-04-30 00:00:00         NaN
# Regional                           NaN                  NaN         NaN
# Date Regional      2009-01-03 00:00:00  2012-04-02 00:00:00         NaN
# Distant                            NaN                  NaN         NaN
# Date Distant       2009-08-05 00:00:00  2012-06-19 00:00:00         NaN
# 2nd Ca                             NaN                  NaN         NaN
# Date 2nd Ca        2009-04-09 00:00:00  2012-06-13 00:00:00         NaN
# RADCURE-challenge                  NaN                  NaN         NaN
# ContrastEnhanced                   1.0                  1.0    0.489639
# event                              1.0                  1.0    0.465061
# time                           2059.75               4675.0  996.725519

# %%
# Check missing values
df_clean[["time", "event", "Age", "Sex", "ECOG PS", "Smoking PY"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3346 entries, 0 to 3345
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   time        3346 non-null   float64
#  1   event       3346 non-null   int64
#  2   Age         3346 non-null   float64
#  3   Sex         3346 non-null   object
#  4   ECOG PS     3345 non-null   object
#  5   Smoking PY  3341 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 157.0+ KB

# %%
print("Sex:", df_clean["Sex"].unique())
print("ECOG PS:", df_clean["ECOG PS"].unique())
print("Smoking PY:", df_clean["Smoking PY"].unique())
# Out:
# Sex: ['Female' 'Male']
# ECOG PS: ['ECOG 0' 'ECOG 2' 'ECOG 1' 'Unknown' 'ECOG 4' 'ECOG 3' 'ECOG-Pt 2' nan
#  'ECOG 0-1' 'ECOG-Pt 0' 'ECOG-Pt 1']
# Smoking PY: [50 25 15 30 0 55 5 8 20 40 22 35 10 60 2 100 49 67.5 65 45 1 90 80 7 17
#  52 46 '>50' 'na' 43 16 4 3 7.5 37 18 21 32 34 '>20' 47 70 19 14 33 75 0.5
#  9 6 17.5 0.3 240 27.5 78 23 12.5 42 36 150 12 '<20' 74 38 1.5 64 2.5 53
#  '<10' 11 24 nan 44 '>25' 120 110 67 48 62 26 13 13.5 39 115 27 28 135
#  22.5 57 '<5' 86 31 8.5 118 105 108 66 54 37.5 41 56 20.3]

# %%
# Encode Sex using original values from df
df_clean["Sex"] = df["Sex"].map({"Female": 0, "Male": 1})
print(df_clean["Sex"].unique())
# Out:
# [0 1]

# %%
df_clean["ECOG_cleaned"] = (
    df_clean["ECOG PS"]
    .str.extract(r"(\d)")
    .astype(float)
)

# %%
def clean_smoking_py(x):
    try:
        return float(x)
    except:
        if isinstance(x, str):
            x = x.strip()
            if x.startswith(">") or x.startswith("<"):
                return float(x[1:])  # keep numeric estimate
            elif x.lower() in ["na", "unknown"]:
                return None
        return None

df_clean["Smoking_cleaned"] = df_clean["Smoking PY"].apply(clean_smoking_py)

# %%
#Drop rows with any missing values for modeling variables
model_vars = ["time", "event", "Age", "Sex", "ECOG_cleaned", "Smoking_cleaned"]
df_clean = df_clean[model_vars].dropna().reset_index(drop=True)

# %%
#df_clean.head()
#df_clean.isna().sum()
#df_clean.info()
#print("Sex values:\n", df_clean["Sex"].value_counts())
#print("ECOG_cleaned:\n", df_clean["ECOG_cleaned"].value_counts().sort_index())
# Out:
# Sex values:
#  Sex
# 1    2613
# 0     653
# Name: count, dtype: int64
# ECOG_cleaned:
#  ECOG_cleaned
# 0.0    2001
# 1.0    1011
# 2.0     208
# 3.0      40
# 4.0       6
# Name: count, dtype: int64

# %%
# Split by sex (0 = Female, 1 = Male)
kmf = KaplanMeierFitter()
plt.figure(figsize=(8, 6))

for label in [0, 1]:
    mask = df_clean["Sex"] == label
    label_name = "Female" if label == 0 else "Male"
    kmf.fit(durations=df_clean[mask]["time"], event_observed=df_clean[mask]["event"], label=label_name)
    kmf.plot_survival_function(ci_show=False)

plt.title("Kaplan-Meier Curve by Sex")
plt.xlabel("Days Since RT Start")
plt.ylabel("Survival Probability")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#Log-Rank Test (Sex)
group_female = df_clean[df_clean["Sex"] == 0]
group_male = df_clean[df_clean["Sex"] == 1]

results = logrank_test(
    durations_A=group_female["time"],
    durations_B=group_male["time"],
    event_observed_A=group_female["event"],
    event_observed_B=group_male["event"]
)

print("Log-Rank Test p-value:", round(results.p_value, 4))
# Out:
# Log-Rank Test p-value: 0.4238

# %%
# Bin ECOG into 3 categories
df_clean["ECOG_group"] = pd.cut(
    df_clean["ECOG_cleaned"],
    bins=[-1, 0, 2, 5],
    labels=["ECOG 0", "ECOG 1–2", "ECOG ≥3"]
)

# Subset valid rows
ecog_data = df_clean.dropna(subset=["ECOG_group"])

# %%
from lifelines import KaplanMeierFitter
import matplotlib.pyplot as plt

kmf = KaplanMeierFitter()
plt.figure(figsize=(8, 6))

for group in ecog_data["ECOG_group"].unique():
    mask = ecog_data["ECOG_group"] == group
    kmf.fit(ecog_data[mask]["time"], ecog_data[mask]["event"], label=str(group))
    kmf.plot_survival_function(ci_show=False)

plt.title("Kaplan-Meier Curve by ECOG Performance Status")
plt.xlabel("Days Since RT Start")
plt.ylabel("Survival Probability")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#Log-Rank Test for ECOG groups
from lifelines.statistics import multivariate_logrank_test

results = multivariate_logrank_test(
    ecog_data["time"],
    ecog_data["ECOG_group"],
    ecog_data["event"]
)

results.print_summary()
# Out:
# <lifelines.StatisticalResult: multivariate_logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 2
#          test_name = multivariate_logrank_test
#
# ---
#  test_statistic      p  -log2(p)
#          281.01 <0.005    202.71

# %%
from lifelines import CoxPHFitter

# Instantiate and fit the Cox model
cph = CoxPHFitter()
cph.fit(df_clean[["time", "event", "Age", "Sex", "ECOG_cleaned"]], duration_col="time", event_col="event")

# Show model summary
cph.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 3266 total observations, 2241 right-censored observations>
#              duration col = 'time'
#                 event col = 'event'
#       baseline estimation = breslow
#    number of observations = 3266
# number of events observed = 1025
#    partial log-likelihood = -7489.18
#          time fit was run = 2025-07-01 02:00:02 UTC
#
# ---
#               coef exp(coef)  se(coef)  coef lower 95%  coef upper 95% exp(coef) lower 95% exp(coef) upper 95%
# covariate
# Age           0.04      1.04      0.00            0.03            0.04                1.03                1.04
# Sex           0.07      1.07      0.08           -0.08            0.23                0.92                1.26
# ECOG_cleaned  0.57      1.76      0.04            0.49            0.64                1.64                1.90
#
#               cmp to     z      p  -log2(p)
# covariate
# Age             0.00 12.72 <0.005    120.64
# Sex             0.00  0.91   0.36      1.46
# ECOG_cleaned    0.00 15.04 <0.005    167.48
# ---
# Concordance = 0.68
# Partial AIC = 14984.36
# log-likelihood ratio test = 424.49 on 3 df
# -log2(p) of ll-ratio test = 302.16

# %%
#to validate proportional hazards.
#cph.check_assumptions(df_clean[["time", "event", "Age", "Sex", "ECOG_cleaned"]], p_value_threshold=0.05, show_plots=True)

# %%
from sksurv.ensemble import RandomSurvivalForest
from sksurv.util import Surv
from sklearn.model_selection import train_test_split

# Step 1: Prepare survival object
y_rsf = Surv.from_dataframe("event", "time", df_clean)

# Step 2: Select features
X_rsf = df_clean[["Age", "Sex", "ECOG_cleaned", "Smoking_cleaned"]]  # feel free to add more

# Step 3: Split data
X_train, X_test, y_train, y_test = train_test_split(X_rsf, y_rsf, test_size=0.2, random_state=42)

# Step 4: Fit the model
rsf = RandomSurvivalForest(n_estimators=100, min_samples_split=10, min_samples_leaf=15,
                           max_features="sqrt", n_jobs=-1, random_state=42)
rsf.fit(X_train, y_train)
# Out:
# RandomSurvivalForest(min_samples_leaf=15, min_samples_split=10, n_jobs=-1,
#                      random_state=42)

# %%
from sksurv.metrics import concordance_index_censored

cindex_rsf = concordance_index_censored(y_test["event"], y_test["time"], rsf.predict(X_test))
print("RSF Concordance Index:", round(cindex_rsf[0], 3))
# Out:
# RSF Concordance Index: 0.702

# %%
from sklearn.inspection import permutation_importance

# Evaluate permutation importance on test set
result = permutation_importance(
    rsf, X_test, y_test,
    n_repeats=10, random_state=42, n_jobs=-1
)

# Extract and display importance values
importances = result.importances_mean
feature_names = X_rsf.columns

# Plot it
import matplotlib.pyplot as plt

plt.barh(feature_names, importances)
plt.xlabel("Permutation Importance")
plt.title("Random Survival Forest Feature Importance")
plt.tight_layout()
plt.show()

# %%
"""A Random Survival Forest model was trained using Age, Sex, ECOG status, and
Smoking exposure as covariates. The model achieved a concordance index of 0.702,
outperforming the Cox model (C-index = 0.68). ECOG performance status was the most
predictive feature, followed by smoking exposure. The RSF model revealed that non-linear
and interaction effects may exist in the data, offering complementary insights beyond the Cox
regression model.""""
